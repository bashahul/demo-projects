# %%
import pandas as pd

dataset = pd.read_csv("50_Startups.csv")

dataset = pd.get_dummies(dataset, drop_first=1)

dataset.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'Profit',
#        'State_Florida', 'State_New York'],
#       dtype='object')

# %%
independent_data = dataset[['R&D Spend', 'Administration', 'Marketing Spend',
       'State_Florida', 'State_New York']]
dependent_data = dataset[['Profit']]

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(independent_data, dependent_data)

# %%
#train the model
from sklearn.tree import DecisionTreeRegressor

regressor = DecisionTreeRegressor(criterion = 'poisson', splitter = 'best')

regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='poisson')

# %%
# predict using test data
y_predict = regressor.predict(x_test)

# evaludate
from sklearn.metrics import r2_score

r_score = r2_score(y_test, y_predict)

r_score
# Out:
# 0.6614355789324436

# %%
# Option draw graph
from sklearn.tree import plot_tree

plot_tree(regressor)

import matplotlib.pyplot as plotter
