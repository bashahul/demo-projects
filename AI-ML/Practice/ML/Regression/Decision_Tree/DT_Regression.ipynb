# %%
# import lib to process dataset
import pandas as pd

# read csv file
dataset = pd.read_csv("50_Startups.csv")

# preprocess: Classification data to numeric
dataset = pd.get_dummies(dataset, drop_first=1)

# split input and output data
independent = dataset[['R&D Spend', 'Administration', 'Marketing Spend', 'State_Florida', 'State_New York']]
dependent = dataset[['Profit']]

# split training and test set
from sklearn.model_selection import  train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent)

# %%
# train the model using decision tree - regression
from sklearn.tree import DecisionTreeRegressor

regressor = DecisionTreeRegressor(criterion='squared_error', splitter='random') # use optional hyper tuning params 

regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(splitter='random')

# %%
# predict and evaluate the model
y_predict = regressor.predict(x_test)

from sklearn.metrics import r2_score

r_score = r2_score(y_test, y_predict)

r_score
# Out:
# 0.9143756100965951

# %%
# plot the decision tree structure
import matplotlib.pyplot as plotter 

from sklearn import tree

tree.plot_tree(regressor)

plotter.show()
