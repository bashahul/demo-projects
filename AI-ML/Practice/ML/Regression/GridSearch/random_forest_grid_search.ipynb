# %%
import pandas as pd

dataset = pd.read_csv("insurance_pre.csv")

dataset = pd.get_dummies(dataset, drop_first=1)

#dataset.columns

independent_data = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent_data = dataset[['charges']]

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

param_grid = {
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse'],
    'max_features': [None, 'sqrt', 'log2'],
    'n_estimators': [10, 100]
}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3, n_jobs=-1)

grid.fit(independent_data, dependent_data)

print("Best Param", grid.best_params_)

re = grid.cv_results_

table = pd.DataFrame.from_dict(re)

table
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# C:\Users\DevUser\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Best Param {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.091268      0.009851         0.009323        0.000794
# 1        0.632812      0.025042         0.033924        0.003448
# 2        0.061239      0.005458         0.008915        0.001297
# 3        0.472754      0.008830         0.034004        0.002369
# 4        0.061605      0.002404         0.009133        0.000943
# 5        0.478434      0.019756         0.031025        0.001970
# 6        0.279529      0.008750         0.008195        0.000885
# 7        2.470984      0.023979         0.028526        0.001238
# 8        0.165399      0.011553         0.008049        0.000483
# 9        1.479204      0.045120         0.031080        0.003887
# 10       0.171819      0.015744         0.008532        0.001000
# 11       1.463027      0.063599         0.028981        0.001120
# 12       0.066495      0.002792         0.008784        0.000993
# 13       0.597517      0.024207         0.031429        0.001654
# 14       0.055162      0.002340         0.009099        0.000704
# 15       0.469681      0.014136         0.031940        0.002279
# 16       0.055967      0.001239         0.008276        0.000812
# 17       0.459808      0.016159         0.028039        0.004091
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  10
# 1    squared_error               None                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6   absolute_error               None                  10
# 7   absolute_error               None                 100
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  10
# 11  absolute_error               log2                 100
# 12    friedman_mse               None                  10
# 13    friedman_mse               None                 100
# 14    friedman_mse               sqrt                  10
# 15    friedman_mse               sqrt                 100
# 16    friedman_mse               log2                  10
# 17    friedman_mse               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.836428
# 1   {'criterion': 'squared_error', 'max_features':...           0.847937
# 2   {'criterion': 'squared_error', 'max_features':...           0.836105
# 3   {'criterion': 'squared_error', 'max_features':...           0.856830
# 4   {'criterion': 'squared_error', 'max_features':...           0.830625
# 5   {'criterion': 'squared_error', 'max_features':...           0.861137
# 6   {'criterion': 'absolute_error', 'max_features'...           0.819527
# 7   {'criterion': 'absolute_error', 'max_features'...           0.842352
# 8   {'criterion': 'absolute_error', 'max_features'...           0.855964
# 9   {'criterion': 'absolute_error', 'max_features'...           0.855527
# 10  {'criterion': 'absolute_error', 'max_features'...           0.851288
# 11  {'criterion': 'absolute_error', 'max_features'...           0.851527
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.842145
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.846790
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.844557
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.861209
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.835932
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.855445
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.751653           0.832931           0.814224
# 1            0.772495           0.857524           0.817875
# 2            0.754182           0.857093           0.815579
# 3            0.781565           0.857886           0.828060
# 4            0.757894           0.837881           0.826168
# 5            0.781210           0.864449           0.826836
# 6            0.749431           0.841698           0.808384
# 7            0.767559           0.850219           0.825517
# 8            0.783331           0.855629           0.795019
# 9            0.783209           0.852302           0.831078
# 10           0.771158           0.835815           0.818296
# 11           0.776125           0.854134           0.829905
# 12           0.746203           0.853277           0.818177
# 13           0.776507           0.857916           0.820136
# 14           0.768897           0.844831           0.822061
# 15           0.783799           0.862037           0.831066
# 16           0.756990           0.843888           0.822908
# 17           0.775148           0.859918           0.827926
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.827887         0.812624        0.031407               17
# 1            0.838038         0.826774        0.030152                9
# 2            0.824246         0.817441        0.034561               14
# 3            0.839626         0.832793        0.027931                4
# 4            0.825711         0.815656        0.029210               15
# 5            0.835178         0.833762        0.030009                2
# 6            0.832329         0.810274        0.032450               18
# 7            0.832950         0.823719        0.029298               10
# 8            0.845157         0.827020        0.031362                8
# 9            0.844027         0.833229        0.026398                3
# 10           0.828765         0.821065        0.027161               11
# 11           0.839018         0.830142        0.028389                6
# 12           0.816686         0.815298        0.037276               16
# 13           0.835610         0.827392        0.028346                7
# 14           0.819463         0.819962        0.027697               12
# 15           0.839966         0.835615        0.028558                1
# 16           0.836545         0.819253        0.031857               13
# 17           0.840313         0.831750        0.030485                5
