# %%
import pandas as pd

dataset = pd.read_csv("insurance_pre.csv")

dataset = pd.get_dummies(dataset, drop_first=1)

#dataset.columns

independent_data = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent_data = dataset[['charges']]

from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

param_grid = {
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse'],
    'max_features': [None, 'sqrt', 'log2'],
    'splitter': ['best', 'random']
}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3, n_jobs=-1)
grid.fit(independent_data, dependent_data)

print("Best Params :", grid.best_params_)

re = grid.cv_results_

table = pd.DataFrame.from_dict(re)

table
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best Params : {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'best'}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.089673      0.003604         0.010512        0.005199
# 1        0.057548      0.028234         0.010675        0.007318
# 2        0.013663      0.002707         0.006268        0.000746
# 3        0.009682      0.001049         0.005674        0.000582
# 4        0.012159      0.000674         0.005368        0.000465
# 5        0.009530      0.000841         0.005083        0.000509
# 6        0.058053      0.003093         0.005250        0.000844
# 7        0.041467      0.001362         0.005492        0.000809
# 8        0.034580      0.003256         0.004793        0.000389
# 9        0.026473      0.003894         0.005494        0.000656
# 10       0.030865      0.001240         0.004811        0.000217
# 11       0.025074      0.002726         0.004807        0.000210
# 12       0.011291      0.000714         0.005529        0.000212
# 13       0.008882      0.000894         0.005515        0.000624
# 14       0.009824      0.001138         0.005216        0.000350
# 15       0.009138      0.000989         0.005026        0.000322
# 16       0.009650      0.000655         0.005801        0.000633
# 17       0.008137      0.000524         0.004860        0.000704
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6   absolute_error               None           best
# 7   absolute_error               None         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               None           best
# 13    friedman_mse               None         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.718149
# 1   {'criterion': 'squared_error', 'max_features':...           0.644313
# 2   {'criterion': 'squared_error', 'max_features':...           0.734944
# 3   {'criterion': 'squared_error', 'max_features':...           0.748596
# 4   {'criterion': 'squared_error', 'max_features':...           0.723034
# 5   {'criterion': 'squared_error', 'max_features':...           0.680032
# 6   {'criterion': 'absolute_error', 'max_features'...           0.721268
# 7   {'criterion': 'absolute_error', 'max_features'...           0.734713
# 8   {'criterion': 'absolute_error', 'max_features'...           0.735702
# 9   {'criterion': 'absolute_error', 'max_features'...           0.654082
# 10  {'criterion': 'absolute_error', 'max_features'...           0.706906
# 11  {'criterion': 'absolute_error', 'max_features'...           0.680360
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.713520
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.724063
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.727299
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.732338
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.709047
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.674292
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.612606           0.732541           0.700882
# 1            0.599575           0.680202           0.694479
# 2            0.575483           0.729141           0.698080
# 3            0.485577           0.726523           0.630104
# 4            0.649582           0.731478           0.713376
# 5            0.602230           0.650250           0.638483
# 6            0.583781           0.693010           0.727691
# 7            0.604150           0.750981           0.688615
# 8            0.598199           0.716615           0.731214
# 9            0.602166           0.786437           0.784477
# 10           0.665508           0.685123           0.746069
# 11           0.568192           0.661398           0.667503
# 12           0.651520           0.739285           0.737964
# 13           0.613551           0.733247           0.707612
# 14           0.629212           0.727481           0.551793
# 15           0.488820           0.638549           0.708738
# 16           0.621385           0.732376           0.719393
# 17           0.438611           0.688087           0.674527
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.680933         0.689022        0.041923                9
# 1            0.681027         0.659919        0.034457               12
# 2            0.678959         0.683321        0.057672               10
# 3            0.501513         0.618463        0.109620               17
# 4            0.704208         0.704336        0.028865                4
# 5            0.650941         0.644387        0.025140               15
# 6            0.762123         0.697574        0.060999                7
# 7            0.719782         0.699648        0.051984                6
# 8            0.556660         0.667678        0.075115               11
# 9            0.741772         0.713787        0.073596                2
# 10           0.800833         0.720888        0.048098                1
# 11           0.641226         0.643736        0.039828               16
# 12           0.692310         0.706920        0.032672                3
# 13           0.696008         0.694896        0.042665                8
# 14           0.646004         0.656358        0.066134               13
# 15           0.681016         0.649892        0.086373               14
# 16           0.734141         0.703269        0.041949                5
# 17           0.604509         0.616005        0.093401               18
